# %%
class Node():
    def __init__(self,data):
        self.data=data
        self.next=None
#Find the leangth        
def lengthLL(head):
    count=0
    while head is not None:
        count=count+1
        head=head.next
    return count    


#Insert into linklist
def insertNode(head,i,data):
    
    if i<0 and i>lengthLL(head):
        return head
    count=0
    prev=None
    curr=head
    while count<i: #0<2,1<2,2<2
        count=count+1
        prev=curr
        curr=curr.next
        
    newNode=Node(data)
    if prev is not None:
        prev.next=newNode
    else:
        head=newNode
    newNode.next=curr
    return head 




def printLL(head):
    while head is not None:
        print(str(head.data)+"->",end="")
        head=head.next
    print("None")    
        
def takeInput():
    inputList=[int(e) for e in input().split()]
    head=None
    tail=None
    
    for currData in inputList:
        if currData==-1:
            break
        newNode=Node(currData)
        
        if head is None:
            head=newNode
            tail=newNode
        else:
            tail.next=newNode
            tail=newNode
    return head


def reverseLL(head):
    prev=None
    curr=head
    while curr is not None:
        nextN=curr.next
        curr.next=prev
        prev=curr
        curr=nextN
    head=prev #this line made the change because the prev is the heads   
    return head  
    
head=takeInput()
#insertNode(head,2,6)
printLL(head)
reversedHead=reverseLL(head)
printLL(reversedHead)
#print(lengthLL(head))
# Out:
# 1 2 3 4 -1
# 1->2->3->4->None
# 4->3->2->1->None
